# %%
#book name, Author name(min 1) ,isbn number(13 digit conditions)
#serch by book name,by author,by isbn number

class book:
    def __init__(self,Title,Author,ISBN):
        self.Title=title
        self.Author=author
        self.ISBN=Isbn

    def __repr__(self):
        return book(title='{self.Title}',Author='{self.Author}',Isbn='{self.Isbn}')

class library:
    def __init__(self):
        self.book=[]

    def add_book(self,book):
        self.book.append(book)

    def search_by_title(self,title):
        return[book for book in self.book if title.lower() in book.title.lower() ]

    def search_by_Author(self,Author):
        return[book for book in self.book if Author.lower() in book.Author.lower()]

    def search_by_Isbn(self,Isbn):
        return[book for book in self.book if Isbn==book.isbn]

    def display_books(self):
        for book in self.books:
            print(book)

def get_book_deails():
    title=input("Enter book Tile:")
    author=input("Enter book Author:")
    while True:
        isbntemp=input("Enter the ISBN number(13-digits):")
        if len(isbntemp)==13:
            isbn=isbntemp
            break
        else:
            print("Enter 13-digit Isbn number:")
    return book(title,auhor,isbn)
if __name__=="__main__":
    library=Library()

while True:
    print("")
    print("Enter 1 to Add a book:")
    print("Enter 2 to search the title:")
    print("Enter 3 to search the Author:")
    print("Enter 4 to search by ISBN:")
    print("Enter 5 to Display the books ")
    print("Enter 6 to Exit")
    action=int(input("Enter your choices"))

    if action==1:
        book=get_book_details()
        library.add_book(book)
    elif action==2:
        title=input("Enter title to search:")
        print("search results:",library.search_by_title(title))
    elif action==3:
        author=input("Enter author ")
